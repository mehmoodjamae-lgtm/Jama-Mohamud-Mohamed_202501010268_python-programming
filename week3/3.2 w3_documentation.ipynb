# %% [markdown]
# 1.1 What are inputs?
# the inputs are:
#
# Quiz 1 mark (quiz_1)
# Quiz 2 mark (quiz_2)
# Quiz 3 mark (quiz_3)
# user choi8ce(choice) to continue or stop
#
# 1.2 What is the process?
# 1. Read three quiz marks from the user.
# 2. calculate the average mark.
#
# average = quiz_1+quiz_2+quiz_3
#           __________________
#                    3
#
# 4. Display PASS if average is greater than or equal to 50,otherwise display FAIL.
# 5. Ask the user whether to continue entering another students marks.
#
# 1.3 What is the ouput?
#
# average mark
# PASS or FAIL message
# "Program Ended" message
#
# 2. Design the Algorithm
# 2.1 Pseudocode
#
# START
#
# set choice = 'Y'
# while choice == 'Y'
#
# input quiz_1
# input quiz_2
# input quiz_3
# average = (quiz_1+ quiz_2+ Quiz_3) / 3
# if average >=50 then Display "PASS"
#
# Else
# Display "FAIL"
# ENDIF
#
# input choice
# ENDWHILE
# Display "Program Ended"
#
# STOP
